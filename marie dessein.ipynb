# %%
#Il s'agit des indices du panier moyen de consommation pour base 100 en 2000 pour les pays: Allemagne, Suisse, Corée et l'Islande.

# %%
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
plt.title("food indice")
plt.xlabel("year")
plt.ylabel("index")

plt.plot([2005, 2006, 2007, 2008], [105,107,112,118], label='Germany', c='cyan')
plt.legend()
plt.plot([2005, 2006, 2007,2008], [107,116,114,132], label='Iceland', c='red')
plt.legend()
plt.plot([2005, 2006, 2007, 2008], [129, 129, 132, 139], label= 'Korea', c='green')
plt.legend()
plt.plot ([2005, 2006, 2007, 2008],[106, 105, 106, 109], label= 'Switzerland', c='black')
plt.legend()
#Je ne sais pas pourquoi j'ai l'abscisse qui adopte cette échelle, je n'ai pas réussi à la modifier

# %%
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
plt.title("food indice")
plt.xlabel("year")
plt.ylabel("index")
plt.subplot(2,2,1)
plt.plot([2005, 2006, 2007, 2008], [105,107,112,118], label='Germany', c='cyan')
plt.title('Germany')
plt.subplot(2,2,2)
plt.plot([2005, 2006, 2007,2008], [107,116,114,132], label='Iceland', c='red')
plt.title('Iceland')
plt.subplot(2,2,3)
plt.plot([2005, 2006, 2007, 2008], [129, 129, 132, 139], label= 'Korea', c='green')
plt.title('Korea')
plt.subplot(2,2,4)
plt.plot ([2005, 2006, 2007, 2008],[106, 105, 106, 109], label= 'Switzerland', c='black')
plt.title ('Switzerland')
# Out:
# Text(0.5, 1.0, 'Switzerland')
