# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

iris = sns.load_dataset("iris")

# %%
data = pd.read_csv("contaception_en_2000_11entre14.csv", delimiter=';')
print(data)
# Out:
#      period  age_of_woman  abortion_rate
# 0    En2000   entre11et14            0.7
# 1    En2000   entre15et19           23.1
# 2    En2000   entre20et24           35.7
# 3    En2000   entre25et29           24.5
# 4    En2000   entre30et34           16.4
# ..      ...           ...            ...
# 147  En2018   entre25et29           19.3
# 148  En2018   entre30et34           15.7
# 149  En2018   entre35et39           10.9
# 150  En2018   entre40et44            4.4
# 151  En2018     45et_plus            0.3
#
# [152 rows x 3 columns]

# %%
En2000 = data[data.period == "En2000"]
print(En2000)
# Out:
#    period  age_of_woman  abortion_rate
# 0  En2000   entre11et14            0.7
# 1  En2000   entre15et19           23.1
# 2  En2000   entre20et24           35.7
# 3  En2000   entre25et29           24.5
# 4  En2000   entre30et34           16.4
# 5  En2000   entre35et39           11.4
# 6  En2000   entre40et44            4.1
# 7  En2000     45et_plus            0.3

# %%
En2001 = data[data.period == "En2001"]
print(En2001)
# Out:
#     period  age_of_woman  abortion_rate
# 8   En2001   entre11et14            0.6
# 9   En2001   entre15et19           23.8
# 10  En2001   entre20et24           36.9
# 11  En2001   entre25et29           25.9
# 12  En2001   entre30et34           16.8
# 13  En2001   entre35et39           10.9
# 14  En2001   entre40et44            3.9
# 15  En2001     45et_plus            0.4

# %%
En2002= data[data.period == "En2002"]
print(En2002)
# Out:
#     period     age_of_woman  abortion_rate
# 16  En2002      entre11et14            0.6
# 17  En2002      entre15et19           25.6
# 18  En2002      entre20et24           38.8
# 19  En2002      entre25et29           26.4
# 20  En2002      entre30et34           17.4
# 21  En2002      entre35et39           10.8
# 22  En2002      entre40et44            4.4
# 23  En2002  entre45_et_plus            0.4

# %%
En2003 = data[data.period == "En2003"]
print(En2003)
# Out:
#     period     age_of_woman  abortion_rate
# 24  En2003      entre11et14            0.7
# 25  En2003      entre15et19           25.9
# 26  En2003      entre20et24           41.1
# 27  En2003      entre25et29           27.9
# 28  En2003      entre30et34           18.0
# 29  En2003      entre35et39           11.6
# 30  En2003      entre40et44            4.3
# 31  En2003  entre45_et_plus            0.3

# %%
En2004 = data[data.period == "En2004"]
print(En2004)
# Out:
#     period  age_of_woman  abortion_rate
# 32  En2004   entre11et14            0.7
# 33  En2004   entre15et19           25.4
# 34  En2004   entre20et24           39.1
# 35  En2004   entre25et29           26.8
# 36  En2004   entre30et34           17.0
# 37  En2004   entre35et39           12.0
# 38  En2004   entre40et44            4.3

# %%
En2005 = data[data.period == "En2005"]
print(En2005)
# Out:
#     period     age_of_woman  abortion_rate
# 39  En2005  entre45_et_plus            0.4
# 40  En2005      entre11et14            0.7
# 41  En2005      entre15et19           24.6
# 42  En2005      entre20et24           36.2
# 43  En2005      entre25et29           26.5
# 44  En2005      entre30et34           16.4
# 45  En2005      entre35et39           11.0
# 46  En2005      entre40et44            4.1
# 47  En2005  entre45_et_plus            0.3

# %%
En2006 = data[data.period == "En2006"]
print(En2006)
# Out:
#     period     age_of_woman  abortion_rate
# 48  En2006      entre11et14            0.9
# 49  En2006      entre15et19           25.8
# 50  En2006      entre20et24           36.6
# 51  En2006      entre25et29           26.4
# 52  En2006      entre30et34           16.7
# 53  En2006      entre35et39           10.9
# 54  En2006      entre40et44            4.1
# 55  En2006  entre45_et_plus            0.3

# %%
En2007 = data[data.period == "En2007"]
print(En2007)
# Out:
#     period     age_of_woman  abortion_rate
# 56  En2007      entre11et14            0.9
# 57  En2007      entre15et19           26.7
# 58  En2007      entre20et24           37.6
# 59  En2007      entre25et29           26.3
# 60  En2007      entre30et34           17.5
# 61  En2007      entre35et39           11.0
# 62  En2007      entre40et44            4.0
# 63  En2007  entre45_et_plus            0.4

# %%
plt.plot(En2000.age_of_woman, En2000.abortion_rate,label="2000")
plt.plot(En2001.age_of_woman, En2001.abortion_rate,label="2001")
plt.plot(En2002.age_of_woman, En2002.abortion_rate,label="2002")
plt.plot(En2003.age_of_woman, En2003.abortion_rate,label="2003")
plt.plot(En2004.age_of_woman, En2004.abortion_rate,label="2004")
plt.plot(En2005.age_of_woman, En2005.abortion_rate,label="2005")
plt.xlabel('tranches_d_age')
plt.ylabel('taux de avortement en %')
plt.title('représentation du taux de avortement en fonction de certaines tranches de ages sur 6 ans ')
plt.legend()

# %%
import seaborn as sns

# %%
#Ce graphique montre que entre chaque tranches dages les femmes ont un taux de avortement plus ou moins fort en fonction des années. 
#Il y  a un gros pics quand les femmes ont entre 20 et 24 ans et une faible quantitées chez les femmes proche des 40ans 
# Cette courbe illustre aussi une augmentation des rapport entre 15 - 24 ans puis une baisse jusqu'à 30ans, puis un dernier déclin jusq'à 45 ans

# %%
plt.subplot(2,2,1)
sns.scatterplot(data=En2000,x="period", y="abortion_rate")
plt.subplot(2,2,2)
sns.scatterplot(data=En2001,x="period", y="abortion_rate")
plt.subplot(2,2,3)
sns.scatterplot(data=En2002,x="period", y="abortion_rate")
plt.subplot(2,2,4)
sns.scatterplot(data=En2003,x="period", y="abortion_rate")
# Out:
# <AxesSubplot:xlabel='period', ylabel='abortion_rate'>

# %%
plt.subplot(2,2,1)
sns.scatterplot(data=En2000,x="period", y="abortion_rate")
plt.subplot(2,2,2)
sns.scatterplot(data=En2001,x="period", y="abortion_rate")
plt.subplot(2,2,3)
sns.scatterplot(data=En2002,x="period", y="abortion_rate")
plt.subplot(2,2,4)
sns.scatterplot(data=En2003,x="period", y="abortion_rate")
# Out:
# <AxesSubplot:xlabel='period', ylabel='abortion_rate'>

# %%
plt.subplot(2,2,1)
sns.scatterplot(data=En2004,x="period", y="abortion_rate")
plt.subplot(2,2,2)
sns.scatterplot(data=En2005,x="period", y="abortion_rate")
plt.subplot(2,2,3)
sns.scatterplot(data=En2006,x="period", y="abortion_rate")
plt.subplot(2,2,4)
sns.scatterplot(data=En2007,x="period", y="abortion_rate")
# Out:
# <AxesSubplot:xlabel='period', ylabel='abortion_rate'>

# %%
plt.subplot(2,2,1)
sns.scatterplot(data=En2007,x="period", y="abortion_rate")
# Out:
# <AxesSubplot:xlabel='period', ylabel='abortion_rate'>

# %%
#on montre grace a ces nuages de poisns les différents taux d'avortement pour chaque années

# %%
fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# Create the boxplot
bp = ax.boxplot(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-8ca5c9380588> in <module>
#       3 ax = fig.add_axes([0,0,1,1])
#       4 # Create the boxplot
# ----> 5 bp = ax.boxplot(data)
#       6 plt.show()
#
# D:\Users\Anaconda-e\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
